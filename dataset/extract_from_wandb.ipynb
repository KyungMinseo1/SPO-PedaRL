# %%
import wandb
api = wandb.Api(api_key="")
run = api.run("/pegoo-sungkyunkwan-university/train-rl-SPO_LAB/runs/9bdzsxig")
run_server = api.run("/pegoo-sungkyunkwan-university/train-rl-SPO_LAB-server/runs/kxtc6ysy")

# %%
import os, json, shutil
from tqdm import tqdm

os.environ["WANDB_SILENT"] = "true"

api = wandb.Api(api_key="", overrides={"silent": True})
all_data = []

for i in tqdm(range(1, 207)):
    try:
        artifact = api.artifact(
            f"pegoo-sungkyunkwan-university/train-rl-SPO_LAB-server/run-kxtc6ysy-nodes_batch_{i}:latest"
        )
        data_dir = artifact.download(root=f"./Wandb/batch_{i}/")
        for f in os.listdir(data_dir):
            with open(os.path.join(data_dir, f)) as fp:
                data = json.load(fp)
                if isinstance(data, list):
                    all_data.extend(data)
                else:
                    all_data.append(data)
        shutil.rmtree(f"./Wandb/batch_{i}/")
    except Exception as e:
        print(f"Error fetching batch {i}: {e}")
        continue

print(f"총 {len(all_data)}개 데이터 로드 완료")
# Out:
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# ...

# %%
all_data_path = "./Wandb/all_data.json"
with open(all_data_path, "w") as f:
    json.dump(all_data, f, ensure_ascii=False, indent=2)
print(f"✅ All data saved to: {all_data_path}")

import pandas as pd
df = pd.DataFrame(all_data)
df.to_csv("./Wandb/all_data.csv", index=False)
print(f"✅ All data saved to: ./Wandb/all_data.csv")
# Out:
# ✅ All data saved to: ./Wandb/all_data.json
# ✅ All data saved to: ./Wandb/all_data.csv

# %%
all_conversations = []

for i in tqdm(range(1, 207)):
    try:
        artifact = api.artifact(
            f"pegoo-sungkyunkwan-university/train-rl-SPO_LAB-server/run-kxtc6ysy-batch_{i}:latest"
        )
        data_dir = artifact.download(root=f"./Wandb/batch_{i}/")
        for f in os.listdir(data_dir):
            with open(os.path.join(data_dir, f)) as fp:
                data = json.load(fp)
                if isinstance(data, list):
                    all_conversations.extend(data)
                else:
                    all_conversations.append(data)
        shutil.rmtree(f"./Wandb/batch_{i}/")
    except Exception as e:
        print(f"Error fetching batch {i}: {e}")
        continue
# Out:
# ...
#   4%|▍         | 9/206 [00:47<17:14,  5.25s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 8
#       4 try:
#       5     artifact = api.artifact(
#       6         f"pegoo-sungkyunkwan-university/train-rl-SPO_LAB-server/run-kxtc6ysy-batch_{i}:latest"
#       7     )
# ----> 8     data_dir = artifact.download(root=f"./Wandb/batch_{i}/")
#       9     for f in os.listdir(data_dir):
#      10         with open(os.path.join(data_dir, f)) as fp:
#
# File c:\Users\82102\anaconda3\envs\pedagogy\Lib\site-packages\wandb\sdk\artifacts\_validators.py:254, in ensure_logged.<locals>.wrapper(self, *args, **kwargs)
#     252 if self.is_draft():
#     253     raise ArtifactNotLoggedError(fullname=method_fullname, obj=self)
# --> 254 return method(self, *args, **kwargs)
#
# ...

# %%
all_conversations_path = "./Wandb/all_conversations.json"
with open(all_conversations_path, "w") as f:
    json.dump(all_conversations, f, ensure_ascii=False, indent=2)
print(f"✅ All conversations saved to: {all_conversations_path}")
